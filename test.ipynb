# %%
import torch
from transformers import AutoTokenizer
tokenizer = AutoTokenizer.from_pretrained("meta-llama/Llama-3.2-1B-Instruct", torch_dtype=torch.float16)

print(tokenizer.decode(315))
# Out:
#  of

# %%
from queue import Queue
q = Queue()
q.put(0)
q.put(1)
q.queue.insert(0,-1)
print(q.get())
print(q.get())
print(q.get())
# Out:
# -1
# 0
# 1
